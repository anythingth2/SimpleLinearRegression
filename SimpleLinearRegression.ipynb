# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('WWWusage.csv')
series = pd.Series.from_csv('WWWusage.csv')
# Out:
# c:\python36\lib\site-packages\pandas\core\series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
x = pd.DataFrame(dataframe,columns=['time'])
y = pd.DataFrame(dataframe,columns=['value'])

# %%
x_hist = pd.Series([x+1 for x in range(0,230)])
y_hist = pd.Series([0 for x in range(0,230)])
y_hist += y['value'].value_counts().sort_index()
y_hist.fillna(0,inplace=True)

x_hist = pd.DataFrame(x_hist[80:])
y_hist = pd.DataFrame(y_hist[80:])
plt.scatter(x_hist,y_hist)

# %%
rgs = linear_model.LinearRegression()

rgs.fit(x_hist,y_hist.fillna(0))

y_hist_pred = rgs_new.predict(x_hist)

plt.scatter(x_hist,y_hist)
plt.scatter(x_hist,y_hist_pred)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}

# %%
y_pred = rgs.predict(x_hist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-09574770eeb5> in <module>()
# ----> 1 y_pred = rgs.predict(x_hist)
#
# c:\python36\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# c:\python36\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     237         check_is_fitted(self, "coef_")
#     238
# --> 239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
#     241                                dense_output=True) + self.intercept_
#
# ...

# %%
mean = y.mean()
print('Mean =',mean.value)

median = y.median()
print('Median =',median.value)

mode = y.mode()
print('Mode at',mode.values[0][0])

standardDeviation = y.std()
print('Standard Deviation =',standardDeviation.value)
# Out:
# Mean = 137.08
# Median = 138.5
# Mode at 85
# Standard Deviation = 39.9994141371237

# %%
y.plot()

# %%
y.plot.hist()

# %%
y.plot.box()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('time')
ax.set_ylabel('number of users')
plt.scatter(x,y,color='lightblue')
plt.plot(x,y_pred,color='red')

# %%
plt.show()
